# %% [markdown]
# Arrays

# %%
from typing import List

# %%
## Contains Duplicate Elements

class Solution:
    def hasDuplicate(self, nums: List[int]) -> bool:
        freq = {}
        for num in nums:
            if num in freq.keys():
                return True
            else:
                freq[num] = 1
        return False

# %%
## 2 sum problem

class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        freq = {}
        for i in range(len(nums)):
            if target - nums[i] in freq.keys():
                return [freq[target-nums[i]],i]
            freq[nums[i]] = i
        return False

# %%
## Top k frequent elements
### Input - nums = [1,2,2,3,3,3], k = 2
### Output - [2,3]

class Solution:
    def topKFreq(self, nums: List[int], k: int) -> List[int]:
        freq = {}
        for n in nums:
            freq[n] = freq.get(n, 0) + 1

# %%
# Out:
# [1, 2, 3]

# %% [markdown]
# Strings

# %%
## Check if 2 strings are anagrams of each other

class Solution:
    def isAnagram(self, s: str, t: str) -> bool:
        if len(s) != len(t):
            return False
        freq_s = {}
        freq_t = {}
        for i in range(len(s)):
            freq_s[s[i]] = freq_s.get(s[i],0) + 1
            freq_t[t[i]] = freq_t.get(t[i],0) + 1
        return freq_s == freq_t

# %%
# Group Anagrams
## Input -  strs = ["act","pots","tops","cat","stop","hat"]
## Output - [["hat"],["act", "cat"],["stop", "pots", "tops"]]

class Solution:
    def groupAnagrams(self, strs: List[str]) -> List[List[str]]:
        if len(strs) == 1:
            return [strs]
        freq_list = {}
        for st in strs:
            count = [0]*26
            for ch in st:
                count[ord(ch)-ord('a')] += 1
            key = tuple(count)
            freq_list[key] = freq_list.get(key,[]) + [st]
        return list(freq_list.values())

# %%
# Top k frequent elements
## Input - arr = [1,2,2,3,3,3]; k = 2
## Output - [3,2]

## Brute Force Approach
# Time Complexity = O(nlogn) (Because sorting)
# Space Complexity = O(n)

class Solution:
    def topKFrequent(self, nums: List[int], k: int) -> List[int]:
        freq = {}
        for i in nums:
            freq[i] = freq.get(i, 0) + 1
        # freq = {1:1, 2:2, 3:3}
        arr = []
        for num, cnt in freq.items():
            arr.append([cnt, num])
        arr.sort() # Even though its a 2D array, by default, it sorts by the first index of every sub-list
        res = []
        while len(res) < k:
            res.append(arr.pop()[1])
        print(res)
        return res

## Optimized Approach 1 -> Min Heap

import heapq

class Solution:
    def topKFrequent(self, nums: List[int], k: int) -> List[int]:
        freq = {}
        for i in nums:
            freq[i] = freq.get(i, 0) + 1
        # freq = {1:1, 2:2, 3:3}
        heap = []
        for num in freq.keys():
            heapq.heappush(heap, (freq[num], num))
            if len(heap) > k:
                heapq.heappop(heap)
        res = []
        for i in range(k):
            res.append(heapq.heappop(heap)[1])
        return res

# %%
from collections import Counter

nums = [1,2,2,3,3,3]
freq = Counter(nums)
freq
# Out:
# Counter({3: 3, 2: 2, 1: 1})
